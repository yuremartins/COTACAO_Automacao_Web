# %% [raw]
# - importar o selenium
# - importante: baixar o webdriver

# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

navegador = webdriver.Chrome() # abrir o navegador

navegador.get("https://www.google.com/") # entrar no google


# cotação do Dólar
navegador.find_element('xpath', '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação dólar") # encontrar xpath e escrever texto de busca
navegador.find_element('xpath', '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER) # clicar ENTER

cotacao_dolar = navegador.find_element('xpath', '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value') # pegar a cotação do dolar

print(cotacao_dolar)


# cotação do Euro
navegador.get("https://www.google.com/")

navegador.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação euro")
navegador.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)

cotacao_euro = navegador.find_element('xpath','//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute("data-value")
print(cotacao_euro)


# cotação do Ouro
navegador.get("https://www.melhorcambio.com/ouro-hoje") # Entrar no site que contém o valor do Ouro

cotacao_ouro = navegador.find_element('xpath', '//*[@id="comercial"]').get_attribute("value")
cotacao_ouro = cotacao_ouro.replace(",", ".")

print(cotacao_ouro)

navegador.quit()
# Out:
# 5.086412999999999
# 5.5085999999999995
# 314.49

# %% [raw]
# - importar o pandas

# %%
# Importar a lista de produtos
import pandas as pd

tabela = pd.read_excel("Produtos.xlsx")
display(tabela)
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %%
# Recalcular o preço de cada produto 

# atualizar cotação
tabela.loc[tabela["Moeda"] == "Dólar", "Cotação"] = float(cotacao_dolar)
tabela.loc[tabela["Moeda"] == "Euro", "Cotação"] = float(cotacao_euro)
tabela.loc[tabela["Moeda"] == "Ouro", "Cotação"] = float(cotacao_ouro)

# atualizar o preço base reais
tabela["Preço de Compra"] = tabela["Cotação"] * tabela["Preço Original"]

# atuaçizar o preço final
tabela["Preço de Venda"] = tabela["Preço de Compra"] * tabela["Margem"]

display(tabela)
# Out:
#          Produtos  Preço Original  Moeda     Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    5.086413      5086.362136    1.40
# 1   Carro Renault         4500.00   Euro    5.508600     24788.700000    2.00
# 2   Notebook Dell          899.99  Dólar    5.086413      4577.720836    1.70
# 3          IPhone          799.00  Dólar    5.086413      4064.043987    1.70
# 4      Carro Fiat         3000.00   Euro    5.508600     16525.800000    1.90
# 5  Celular Xiaomi          480.48  Dólar    5.086413      2443.919718    2.00
# 6        Joia 20g           20.00   Ouro  314.490000      6289.800000    1.15
#
#    Preço de Venda
# 0     7120.906990
# 1    49577.400000
# 2     7782.125421
# 3     6908.874778
# 4    31399.020000
# 5     4887.839436
# 6     7233.270000

# %%
# Salvar os novos preços dos produtos

tabela.to_excel("Produtos Novo.xlsx", index=False)
